# %% [markdown]
# ##                **PYTHON PROJECT ON SUPERMARKET SALES**

# %% [markdown]
# ## **Introduction to dataset**
#
# supermarket data set explains about the sales across 3
# branches over 3 months( from january 2019 to march 2019).
#
#
#
#
#
# variables used in this dataset are:
#
# 1.**Invoice id**: Computer generated sales slip invoice identification number
#
#
# 2.**Branch**: Branch of supercenter (3 branches are available identified by A, B and C).
#
#
# 3.**City**: Location of supercenters
#
#
# 4.**Customer type**: Type of customers, recorded by Members for customers using member card and Normal for without member card.
#
#
# 5.**Gender**: Gender type of customer
#
#
# 6.**Product line**: General item categorisation groups - Electronic accessories, Fashion accessories, Food and beverages, Health and beauty, Home and lifestyle, Sports and travel
#
#
# 7.**Unit price**: Price of each product in $
#
#
# 8.**Quantity**: Number of products purchased by the customer
#
#
# 9.**Tax**: 5% tax fee for customer buying
#
#
# 10.**Total**: Total price including tax
#
#
# 11.**Date**: Date of purchase (Record available from January 2019 to March 2019)
#
#
# 12.**Time**: Purchase time (10 am to 9 pm)
#
#
# 13.**Payment**: Payment used by the customer for the purchase (3 methods are available – Cash, Credit card and Ewallet)
#
#
# 14.**COGS**: Cost of goods sold
#
#
# 15.**Gross margin percentage**: Gross margin percentage
#
#
# 16.**Gross income**: Gross income
#
# 17.**Rating**: Customer stratification rating on their overall

# %% [markdown]
# ## UNDERSTANDING THE DATASET
#
# 1.**Gross income:** Gross income refers to the total income earned  before taxes and other deductions.
# It represents the revenue that a company earned from selling its goods or services after subtracting the direct costs incurred in producing the goods being sold.
#
# Gross Income = Gross Revenue – Cost of Goods Sold
#
# 2.COGS: Cost of goods sold (COGS) refers to the direct costs of producing the goods sold by a company. This amount includes the cost of the materials and labor directly used to create the good. It excludes indirect expenses, such as distribution costs and sales force costs
#
# 3.Gross margin percentage: The Gross Profit Margin shows the income a company has left over after paying off all direct expenses related to manufacturing a product or providing a service.
#
# The formula to calculate gross margin as a percentage is Gross Margin = (Total Revenue – Cost of Goods Sold)/Total Revenue x 100
#
# Rest of the columns are self explanatory.

# %% [markdown]
# ## Importing necessary libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#reading the given excel file and assigning it to sm_sales   
sm_sales=pd.read_excel("/content/Python_mandatory_project_supermarket_sales (1).xlsx")  

sm_sales.head()         #reading first 5 rows
# Out:
#     Invoice ID Branch city code  Customer type  Gender Product code  \
# 0  750-67-8428      A        CT1        Member  Female          PD1
# 1  226-31-3081      C        CT3        Normal  Female          PD2
# 2  631-41-3108      A        CT1        Normal    Male          PD3
# 3  123-19-1176      A        CT1        Member    Male          PD1
# 4  373-73-7910      A        CT1        Normal    Male          PD4
#
#   Unit price  Quantity   Tax 5%     Total       Date      Time      Payment  \
# 0      74.69         7  26.1415  548.9715 2019-01-05  13:08:00      Ewallet
# 1      15.28         5   3.8200   80.2200 2019-03-08  10:29:00         Cash
# 2      46.33         7  16.2155  340.5255 2019-03-03  13:23:00  Credit card
# 3      58.22         8  23.2880  489.0480 2019-01-27  20:33:00      Ewallet
# 4      86.31         7  30.2085  634.3785 2019-02-08  10:37:00      Ewallet
#
#      cogs  gross margin percentage  gross income  Rating
# ...

# %%
# Q1. is your SUPERMARKET more popular with males or females.

sns.countplot(x='Gender', data=sm_sales)        #we have 1 variable of categorical type ,so using countplot function to see the results                
plt.show()

# %% [markdown]
# from the above graph, we conclude that supermarket is equally
# popular among males and females.

# %%
#Q2.what does the customer rating look like and comment on its distribution?
sns.displot(sm_sales, x="Rating", bins = 6)              # we have 1 variable of numerical type ,so using histogram to see the results 
plt.show()

# %% [markdown]
# customer rating is gighest between 6 - 8,distribution is more or less symmetric.

# %%
#Q3.what can you say about the aggregate sales across the branches?
plt.figure(figsize=(10,5))                                     #marking figure size
sns.boxplot(x='Branch', y='Total', data=sm_sales)              #we have 1 variable of numerical type and other variable of categorical type
                                                               #so using box plot to see the result as it gives better idea 
plt.show()

# %% [markdown]
# here we have plotted the box plot between branch and total sales,aggregate sales for branch c is more than a and b.

# %%
#4. what is the most popular payment method used by customers?

sns.countplot(x='Payment', data=sm_sales)    ##we have 1 variable of categorical type ,so using countplot function to see the results
plt.show()

# %% [markdown]
# from the above graph it is clear that, Ewallet and cash payment are equally  the most popular payment method

# %%
#Q5.does gross income affect customer rating?

sns.scatterplot(x= "gross income", y= "Rating", data = sm_sales)  #scatter plot is used to find relation between 
                                                                  # two numerical data
plt.show()

# %% [markdown]
# there is no direct relation between gross income and rating,
# but from above graph it can be seen that as the gross income increases, frequency of rating decreases i.e people dont rate much.

# %%
#Q6. which is the most profitable branch?
sns.barplot(data = sm_sales, x = 'Branch', y = 'gross income', color = 'red',ci=None)  #we have 1 variable of numerical type and other variable of categorical type
                                                                                       #so using bar plot to see the result.
plt.show()

# %% [markdown]
# gross income for branch 'C' is highest, so it is the most profitable branch.

# %%
#7.create a box plot between gender and gross income.

sns.boxplot(x='Gender', y='gross income', data=sm_sales)
plt.show()

# %% [markdown]
# gross income for females is more as compared to males

# %%
#Q8.CAN YOU SEE ANY TIME TREND IN GROSS INCOME?
plt.figure(figsize=(10,5))
sns.lineplot( x = "Date", y="gross income",data=sm_sales)           #lineplot is used to see the trend                  
             
plt.show()

# %% [markdown]
# trend is more or less sideways,its peak is in mid february i.e during valentines week.

# %%
#Q.9 what is the spending pattern of both males and females,in which category do they spend more?
sns.countplot(x='Gender', hue='Product code', data=sm_sales)           # 'hue' is used when we compare two categories,x axis is divided on the basis of hue 
plt.show()

# %% [markdown]
# females spend mostly in PD6 category,
# males spend mostly in PD1 category

# %%
#10. how many products bought by the customers?
sm_sales["Quantity"].count()                     #using .count() funtion to count the no. of products
# Out:
# 1000

# %% [markdown]
# total 1000 products bought by the customers

# %%
#Q.13 which product line should super market more focus on?
sns.countplot(x='Product code', data=sm_sales)         ##we have 1 variable of categorical type ,so using countplot function to see the results      
plt.show()

# %% [markdown]
# super matrket should focus on PD1 product line

# %%
#Q14. which city should be chosen for expansion and what products should be focussed on?
plt.figure(figsize=(18,8))                                                       #marking figure size
sns.countplot(x='city code ', hue='Product code', data=sm_sales)                 #using countplot for two categorical data
plt.show()

# %% [markdown]
# CT3 should be chosen for expansion , PD3 and  PD4 product line should be more focussed
